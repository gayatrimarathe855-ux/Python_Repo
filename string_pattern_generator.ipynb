# %%
s = input("Enter a 3 letter string: ")

for i in range(5):
    if i == 0 or i == 4:
        print(s[0] + "***" + s[0])
    elif i == 1 or i == 3:
        print("*" + s[1] + "*" + s[1] + "*")
    else:
        print("**" + s[2] + "**")
# Out:
# Enter a 3 letter string: MOM
# M***M
# *O*O*
# **M**
# *O*O*
# M***M
