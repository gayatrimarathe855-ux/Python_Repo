# %%
n = int(input("Enter a number: "))

rev = 0

while n > 0:
    digit = n % 10
    rev = rev * 10 + digit
    n = n // 10

print("Reverse =", rev)
# Out:
# Enter a number: 1234
# Reverse = 4321

# %%
n = int(input("Enter a number: "))

while n>0:
  digit=n%10
  print(digit)
  n=n//10
# Out:
# Enter a number: 1234
# 4
# 3
# 2
# 1
