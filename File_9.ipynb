# %%
a={1,2,3,2,4,1,5,4,7,6,3,2}
type(a)
# Out:
# set

# %%
a={1,2,3,2,4,1,5,4,7,6,3,2}
print(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
#intersection
a={1,2,4,3,9}
b={3,9,7,2,5}
print(a & b)
# Out:
# {9, 2, 3}

# %%
#union
a={1,2,4,3,9}
b={3,9,7,2,5}
print(a|b)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
#difference
a={1,2,4,3,9}
b={3,9,7,2,5}
print(a-b)
# Out:
# {1, 4}

# %%
#symmentric diffrece
a={1,2,4,3,9}
b={3,9,7,2,5}
(a^b)-(a^b)
# Out:
# set()

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 7, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.intersection(b)
# Out:
# {2, 3, 9}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.difference(b)
# Out:
# {1, 4}

# %%
a={1,2,4,3,9}
b={3,9,7,2,5}
a.symmetric_difference(b)
# Out:
# {1, 4, 5, 7}

# %%
(a|b)-(a&b)
# Out:
# {1, 4, 5, 7}

# %%
#dictionaries
dct={1:"ABC",2:"PQR"}
print(dct)
# Out:
# {1: 'ABC', 2: 'PQR'}

# %%
for i in dct:
  print(i)
# Out:
# 1
# 2

# %%
for i,j in dct.items():
  print(i,j)
# Out:
# 1 ABC
# 2 PQR

# %%
std={ 1:"gayatri", 2:"priyanka", 3:"rushi", 4:"om", 5:"janhavi"}
for key,value in std.items():
  print(f"Rool No {key} is {value}")
# Out:
# Rool No 1 is gayatri
# Rool No 2 is priyanka
# Rool No 3 is rushi
# Rool No 4 is om
# Rool No 5 is janhavi

# %%
std[3]="anu"
print(std)
# Out:
# {1: 'gayatri', 2: 'priyanka', 3: 'anu', 4: 'om', 5: 'janhavi'}

# %%
std[6]="ABC"
print(std)
# Out:
# {1: 'gayatri', 2: 'priyanka', 3: 'anu', 4: 'om', 5: 'janhavi', 6: 'ABC'}

# %%
std.get(2)
# Out:
# 'priyanka'

# %%
std.get(50,"not found")
# Out:
# 'not found'

# %%
sample={"days":["mon","tue","wed","thu",]
        ,"planets":["sun","satern","earth"]}
for key, value in sample.items():
  print(f" {key} {value}")
# Out:
#  days ['mon', 'tue', 'wed', 'thu']
#  planets ['sun', 'satern', 'earth']

# %%
sample={"aaa":"123",1.14:"1.12"}
for key, value in sample.items():
  print(f" {key} {value}")
# Out:
#  aaa 123
#  1.14 1.12

# %%
n = int(input("Enter n: "))

for i in range(n, 0, -1):
    print("*" * i)

# %%
n=5

for i in range(0, n, +1):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
